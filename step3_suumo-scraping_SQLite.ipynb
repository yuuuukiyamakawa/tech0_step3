# %%
# スクレイピング
# SUUMOの物件情報を自動取得（スクレイピング）したのでコードを解説する。 https://qiita.com/tomyu/items/a08d3180b7cbe63667c9
# SUUMOのデータを前処理したので解説する。 https://qiita.com/tomyu/items/e039bcf2a44ad2e83b94
# SUUMOの前処理でもう少し手を加えたので解説する。 https://qiita.com/tomyu/items/ba376faa7a7939941eee

# %%
# SQLite
# 【vol.027】Pythonでデータベースを扱ってみよう | 中学生でもわかるPython入門シリーズ https://www.youtube.com/watch?v=nbIqlV0X2yQ

# %%
# ライブラリのインポート
import requests
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd
import re  # 正規表現の使用

# import gspread
# from oauth2client.service_account import ServiceAccountCredentials
import sqlite3

from dotenv import load_dotenv  # 環境変数の読み込みに使用。https://chat.openai.com/share/f6530203-f855-42b2-9488-089cc957dc63  # Pythonで.envファイルから環境変数を設定する https://qiita.com/wooooo/items/7b57eaf32c22195df843
import os  # Pythonの標準ライブラリの一部で、オペレーティングシステムに関連する機能を提供します。os.getenv はその中の一つの関数です。https://chat.openai.com/share/c3ef4fc3-51bf-4063-87f8-6c1cf65e5bfd

# %%
# 環境変数の読み込み
# load_dotenv()

# %%
# # 使用するGoogleSheetsAPI、GoogleDriveAPI情報の指定
# SCOPES = [
#     'https://spreadsheets.google.com/feeds',
#     'https://www.googleapis.com/auth/drive'
# ]

# # 秘密鍵のjsonファイルを指定
# SEVICE_ACCOUNT_FILE = os.getenv('SEVICE_ACCOUNT_FILE')

# # 認証情報を作成
# credentials = ServiceAccountCredentials.from_json_keyfile_name(SEVICE_ACCOUNT_FILE, SCOPES)

# # スプレッドシートの操作権を取得
# gs = gspread.authorize(credentials)

# # 編集するスプレッドシートとワークシートの指定
# SPREADSHEET_KEY = os.getenv('SPREADSHEET_KEY')
# workbook = gs.open_by_key(SPREADSHEET_KEY)
# worksheet = workbook.worksheet("シート1")

# %%
# 関数の定義

# 文字+数字+文字 → 文字
def objnumobj_num(x):
    return re.sub(r'\w+?([0-9]+)\w+',r'\1',x)
    # re.sub()は、第一引数に正規表現パターン、第二引数に置換先文字列、第三引数に処理対象の文字列を指定。https://note.nkmk.me/python-str-replace-translate-re-sub/#resub-resubn
    # r''は"\"を特殊シーケンスとして認識させるために必要なもの。
    # \wは、任意の英数字で、「1, 2, 333, 12aa, ab」などのこと。漢字にも使えている。☛ なぜ漢字は/Wではないのか？https://chat.openai.com/share/6f7b2fd9-26a1-49da-bf35-501d4649b6fd
    # +?は直前のパターンを1回以上繰り返す、という意味なので、"\w+?"で「1文字以上の英数字」を表す。
    # +は直前のパターンを1回以上繰り返す、という意味なので、"([0-9]+)"は「1文字以上の数字」を表す。また、([0-9]+)の()はキャプチャグループ化を意味する。
    # "\1"は1番目のキャプチャグループを意味する。つまり、ココでは([0-9]+)になる。https://chat.openai.com/share/e08ae899-4426-48df-aaf6-bdf78e87fd9e

# 5万円 → 5
def drop_man(x):
    return re.sub(r'([0-9]+)万円+',r'\1',x)
    # 万円を"\w+"にすると、31.2万円 → 3.2。32.2 → 3.2になる。なぜ？

# 数字+文字 → 文字
def numobj_num(x):
    return re.sub(r'([0-9]+)\w+',r'\1',x)
# ([0-9]+)\w+は、1文字以上の数字＋1文字以上の英数字。"\1"は1番目のキャプチャグループを返す。

# 英字以降を切り落とし
def drop_behind_alfa(x):
    return re.sub('[a-z]\w+','',x)

# 文字列の検索。返り値はTrue,False
def search_object(search, object):
    return bool(re.search(search,object))
# re.search(検索パターン, 検索対象)で該当すれば、matchしたオブジェクトを返す。https://note.nkmk.me/python-re-match-search-findall-etc/#search
# ここでは、bool()を用いているので、re.search()でマッチすればTrue、NoneであればFalseを返す。

# 最後の数字列を取りだす
def lastnum(x):
    nums = re.findall('[0-9]+', x)
    
    if nums:
        return nums[-1]
    else:
        # 数字が見つからない場合の処理。0を返す。
        return 0

# 文字+数字 → 数字
def get_objnum(x):
    return re.search(r'([A-Z]?)([0-9]+)',x).group()  # re.search()でマッチしたオブジェクトに対して、.group()でオブジェクトのテキストデータのみ出力

# 「地下」という文字列が入っていればその階数、入っていなければ0
def underground(x):
    return search_object('地下',x)*objnumobj_num(x)+(1-search_object('地下',x))*'0'

def list_min(x):
    lists = re.findall(r'\w?\d+', x)
    converted_list = []
    
    for item in lists:
        if item.startswith('B'):
            converted_item = int(item.replace('B', '-'))
        else:
            converted_item = int(item)
        
        converted_list.append(converted_item)
        
    return min(converted_list)

# %%
data_list = []

# suumoサイトで東京都港区の賃貸物件を検索
url = 'https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&ta=13&sc=13103&cb=0.0&ct=9999999&mb=0&mt=9999999&et=9999999&cn=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&sngz=&po1=25&pc=50&page={}'
# pc=○○の所で一度に表示する件数を設定。pc=30では約20min、pc=50では約8min。

# スクレイピングページ数の指定
max_page = 10

# 1-指定ページまでをスクレイピング
for i in range(1, max_page + 1):

    target_url = url.format(i)
    res = requests.get(target_url)
    res.encoding = 'utf-8'

    # スクレイピング先のサーバー負荷軽減の為、1ページ情報を取得後に1秒のディレイ
    sleep(1)

    soup = BeautifulSoup(res.text, 'html.parser')

    # 物件情報の取得
    contents = soup.find_all('div',class_= 'cassetteitem')

    # 1物件ずつ情報の取得
    for content in contents:
        
        # 物件名、住所、アクセス、築年数、階建 情報ブロック
        detail = content.find('div',class_='cassetteitem-detail')
        # 階数、賃料、管理費、敷金、礼金、間取り、面積 情報ブロック
        table = content.find('table', class_='cassetteitem_other')

        # 物件名、住所、アクセス、築年数、階建の取得
        title = content.find('div', class_= 'cassetteitem_content-title').text
        address = content.find('li', class_= 'cassetteitem_detail-col1').text
        access_1 = content.find('li', class_= 'cassetteitem_detail-col2').find_all()[0].text
        access_2 = content.find('li', class_= 'cassetteitem_detail-col2').find_all()[1].text
        access_3 = content.find('li', class_= 'cassetteitem_detail-col2').find_all()[2].text
        age = content.find('li', class_= 'cassetteitem_detail-col3').find_all('div')[0].text
        story = content.find('li', class_= 'cassetteitem_detail-col3').find_all('div')[1].text

        # テーブルの行情報の取得
        tr_tags = table.find_all('tr',class_='js-cassette_link')

        # リスト1列毎に階数、賃料、管理費、敷金、礼金、間取り、面積の取得
        for tr_tag in tr_tags:
            floor, price, first_fee, capacity = tr_tag.find_all('td')[2:6]

            fee, management_fee = price.find_all('li')
            deposit, gratuity = first_fee.find_all('li')
            madori, menseki = capacity.find_all('li')

            # 取得した情報を辞書に格納
            data = {
                'title':title,
                'address':address,
                'access_1':access_1,
                'access_2':access_2,
                'access_3':access_3,
                'age':age,
                'story':story,
                'floor':floor.text,
                'fee':fee.text,
                'management_fee':management_fee.text,
                'deposit':deposit.text,
                'gratuity':gratuity.text,
                'madori':madori.text,
                'menseki':menseki.text
            }

            data_list.append(data)

# データフレームを作成する
df = pd.DataFrame(data_list)

# カラム名の変更
df.columns = ['物件名', '住所', 'アクセス1', 'アクセス2', 'アクセス3', '築年数', '階建', '階数', '賃料', '管理費', '敷金', '礼金', '間取り', '面積']

# %%
# データのクレンジング

# 築年数
df.loc[df['築年数']=='新築','築年数'] = '築0年'                              # 新築は築0年。
                                                                            # df.loc[df['築年数']=='新築']は、'築年数'カラムの値が'新築'のものを抽出。
                                                                            # df.loc[df['築年数']=='新築','築年数']は抽出したデータフレームから、'築年数'カラムのデータを抽出したもの。ここでは、シリーズ形式。['築年数']であればデータフレーム形式。https://qiita.com/Tusnori/items/31746dd1c55ecff2bb22
df['築年数'] = df['築年数'].map(lambda x: objnumobj_num(x)).astype(int)     # 築5年 → 5、int型に変更

# %%
# 階建
df.loc[df['階数']=='平屋', '階数'] = '1階建'
df['地下'] = df['階建'].map(lambda x: underground(x)).astype(int)
df['地上'] = df['階建'].map(lambda x: lastnum(x)).astype(int)
df['階建'] = df['地上'] + df['地下']

# %%
# 階数
df['階数'] = df['階数'].str.strip()
df.loc[df['階数']=='-','階数'] = '1階'
df['階数'] = df['階数'].map(lambda x: numobj_num(x))
df['階数'] = df['階数'].map(lambda x: list_min(x))

# %%
# 賃料
df['賃料'] = df['賃料'].map(lambda x: drop_man(x)).astype(float)            # 5万 → 5、float型に変更

# %%
# 管理費
df.loc[df['管理費']=='-','管理費'] = '0円'                                  # '-' → '0円'
df['管理費'] = df['管理費'].map(lambda x:numobj_num(x)).astype(int)         # 5円 → 5、int型に変更

# %%
# 敷金
df.loc[df['敷金']=='-','敷金'] = '0万円'                                    # '-' → '0万円'
df['敷金'] = df['敷金'].map(lambda x: drop_man(x)).astype(float)            # 5万円 → 5、float型に変更

# %%
# 礼金
df.loc[df['礼金']=='-','礼金'] = '0万円'                                    # '-' → '0万円'
df['礼金'] = df['礼金'].map(lambda x: drop_man(x)).astype(float)            # 5万円 → 5、float型に変更

# %%
# 間取り
df.loc[df['間取り']=='ワンルーム','間取り'] = '1'                            # 'ワンルーム' → '1'   間取りのSはサービスルーム
df['間取り_部屋数'] = df['間取り'].map(lambda x:numobj_num(x)).astype(int)

# %%
# 面積
df['面積'] = df['面積'].map(lambda x: drop_behind_alfa(x)).astype(float)    # 5m2 → 5

# %%
df = df.sort_values('物件名')

# %%
# df['階数'].sort_values().unique()

# %%
df.head()
df1 = df.drop_duplicates(subset=['物件名'                                                                                   ],keep='first')
df2 = df.drop_duplicates(subset=['物件名', '住所'                                                                           ],keep='first')
df3 = df.drop_duplicates(subset=['物件名', '住所',                          '賃料', '管理費', '敷金', '礼金', '間取り', '面積'],keep='first')
df4 = df.drop_duplicates(subset=['物件名', '住所', '築年数', '階建', '階数', '賃料', '管理費', '敷金', '礼金', '間取り', '面積'],keep='first')
df5 = df.drop_duplicates(subset=[                  '築年数', '階建', '階数', '賃料', '管理費', '敷金', '礼金', '間取り', '面積'],keep='first')

# %%
print('df :',len(df))
print('df1:',len(df1))
print('df2:',len(df2))
print('df3:',len(df3))
print('df4:',len(df4))
print('df5:',len(df5))
# Out:
# df : 2619
# df1: 496
# df2: 497
# df3: 2298
# df4: 2378
# df5: 2008

# %%
# # dfから値を習得
# values = [df_tmp.columns.values.tolist()] + df_tmp.values.tolist()

# # スプレッドシートにデータを追加
# worksheet.update("A1", values)
# Out:
# C:\Users\yuki_yamakawa\AppData\Local\Temp\ipykernel_41532\1678576455.py:5: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   worksheet.update("A1", values)
# {'spreadsheetId': '1RN3MBSM-864r1Me1hdgOZmWzXY0NLMJsb7O6FBogg6k',
#  'updatedRange': "'シート1'!A1:N30564",
#  'updatedRows': 30564,
#  'updatedColumns': 14,
#  'updatedCells': 427896}

# %%
# SQLiteでDB化
# ファイルの作成
db_name = 'sample_sqlite.db'

# 接続
conn = sqlite3.connect(db_name)

# %%
conn

# %%
df5.to_sql('suumo', conn, if_exists='replace')
# Out:
# 2008

# %%
c = conn.cursor()

# %%
query = 'SELECT * FROM suumo'
c.execute(query)

# %%
# 1行目のデータを取得
c.fetchone()  # 繰り返して実行すると、1行目、2行目、3行目と取得する行が変わる

# %%
c.fetchall()
# Out:
# []

# %%
for row in c.execute(query):
    print(row)
# Out:
# (0, '東京メトロ千代田線 赤坂駅 11階建 築11年', '東京都港区赤坂２', '東京メトロ千代田線/赤坂駅 歩5分', '東京メトロ銀座線/溜池山王駅 歩6分', '東京メトロ丸ノ内線/赤坂見附駅 歩9分', 11, 11, '9', 31.2, 15000, 31.2, 31.2, '2LDK', 53.75, 0, 11, 2)
# (1, '東京メトロ千代田線 赤坂駅 11階建 築11年', '東京都港区赤坂２', '東京メトロ千代田線/赤坂駅 歩5分', '東京メトロ銀座線/溜池山王駅 歩6分', '東京メトロ丸ノ内線/赤坂見附駅 歩9分', 11, 11, '6', 32.2, 15000, 32.2, 32.2, '2LDK', 55.36, 0, 11, 2)
# (2, '東京メトロ銀座線 外苑前駅 地下1地上3階建 築21年', '東京都港区南青山４', '東京メトロ銀座線/外苑前駅 歩9分', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ
 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '9', 16.0, 15000, 16.0, 16.0, '1', 25.37, 0, 18, 1)
# (27, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '11', 17.0, 15000, 17.0, 17.0, '1K', 25.4, 0, 18, 1)
# (28, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '8', 34.0, 10000, 0.0, 34.0, '2LDK', 57.95, 0, 18, 2)
# (29, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '7', 33.9, 30000, 0.0, 33.9, '2LDK', 57.95, 0, 18, 2)
# (30, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '8', 34.0, 30000, 0.0, 34.0, '2LDK', 57.95, 0, 18, 2)
# (31, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '11', 34.9, 30000, 0.0, 34.9, '2LDK', 57.95, 0, 18, 2)
# (32, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '12', 35.0, 30000, 0.0, 35.0, '2LDK', 57.95, 0, 18, 2)
# (33, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '9', 36.5, 20000, 0.0, 36.5, '2LDK', 57.95, 0, 18, 2)
# (34, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '13', 37.0, 20000, 0.0, 37.0, '2LDK', 57.95, 0, 18, 2)
# (35, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '14', 39.0, 30000, 39.0, 39.0, '2LDK', 57.95, 0, 18, 2)
# (37, 'パークホームズ浜松町', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩6分', '都営浅草線/大門駅 歩7分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 18, '14', 46.0, 0, 46.0, 92.0, '2LDK', 57.95, 0, 18, 2)
# (38, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '5', 15.7, 15000, 15.7, 15.7, '1K', 26.07, 0, 15, 1)
# (39, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '9', 16.0, 17000, 16.0, 16.0, '1K', 26.01, 0, 15, 1)
# (40, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '8', 19.8, 10000, 19.8, 19.8, '1DK', 30.1, 0, 15, 1)
# (41, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '10', 25.0, 0, 25.0, 25.0, '1LDK', 37.08, 0, 15, 1)
# (42, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '2', 34.9, 20000, 34.9, 34.9, '2LDK', 57.74, 0, 15, 2)
# (43, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '2', 35.0, 20000, 35.0, 35.0, '2LDK', 57.03, 0, 15, 2)
# (45, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '2', 35.8, 20000, 35.8, 53.7, '2LDK', 57.74, 0, 15, 2)
# (46, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '2', 36.5, 20000, 36.5, 73.0, '2LDK', 57.74, 0, 15, 2)
# (47, 'パークコート南麻布', '東京都港区南麻布１', '南北線/麻布十番 歩6分', '南北線/白金高輪 歩10分', '', 4, 15, '2', 37.5, 10000, 37.5, 75.0, '2LDK', 57.03, 0, 15, 2)
'東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩13分', '東京メトロ日比谷線/広尾駅 歩16分', '東京メトロ千代田線/乃木坂駅 歩19分', 11, 14, '7', 58.0, 30000, 0.0, 0.0, '2LDK', 82.75, 0, 14, 2)
# (89, 'ミレアコート南青山', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩13分', '東京メトロ日比谷線/広尾駅 歩16分', '東京メトロ千代田線/乃木坂駅 歩19分', 11, 14, '13', 67.0, 30000, 0.0, 0.0, '3LDK', 102.39, 0, 14, 3)
# (91, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '7', 15.8, 0, 0.0, 0.0, '1', 23.94, 1, 45, 1)
# (92, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '5', 16.4, 0, 0.0, 16.4, '1', 25.73, 1, 45, 1)
# (93, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '4', 19.1, 12000, 19.1, 19.1, '1', 31.01, 1, 45, 1)
# (94, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '21', 23.0, 0, 23.0, 23.0, '1K', 30.15, 1, 45, 1)
# (95, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '17', 27.5, 0, 27.5, 27.5, '1LDK', 38.67, 1, 45, 1)
# (96, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '10', 31.0, 40000, 31.0, 31.0, '2LDK', 55.88, 1, 45, 2)
# (97, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '23', 35.0, 0, 35.0, 35.0, '1LDK', 50.07, 1, 45, 1)
# (98, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '26', 39.8, 20000, 39.8, 39.8, '2LDK', 56.72, 1, 45, 2)
# (99, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '28', 42.0, 0, 42.0, 42.0, '1LDK', 56.72, 1, 45, 1)
# (100, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '18', 44.0, 0, 88.0, 44.0, '2LDK', 60.24, 1, 45, 2)
# (101, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '8', 41.0, 40000, 41.0, 41.0, '1LDK', 64.87, 1, 45, 1)
# (102, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '11', 41.0, 40000, 41.0, 41.0, '2LDK', 57.67, 1, 45, 2)
# (103, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '31', 55.0, 0, 55.0, 55.0, '2LDK', 71.99, 1, 45, 2)
# (104, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '17', 60.0, 0, 60.0, 60.0, '2LDK', 84.66, 1, 45, 2)
# (105, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '4', 64.0, 40000, 64.0, 64.0, '2LDK', 83.41, 1, 45, 2)
# (106, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '29', 73.0, 20000, 73.0, 73.0, '2LDK', 81.25, 1, 45, 2)
# (107, '白金ザ・スカイ イースト棟', '東京都港区白金１', '東京メトロ南北線/白金高輪駅 歩3分', '都営大江戸線/麻布十番駅 歩13分', '都営浅草線/泉岳寺駅 歩13分', 0, 46, '42', 85.0, 0, 85.0, 85.0, '3LDK', 83.08, 1, 45, 3)
# (108, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '9', 18.3, 13000, 27.45, 18.3, '1', 30.02, 1, 37, 1)
# (109, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '8', 22.3, 13000, 33.45, 22.3, '1LDK', 35.02, 1, 37, 1)
# (110, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '6', 24.5, 0, 49.0, 24.5, '1LDK', 37.52, 1, 37, 1)
# (111, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '8', 25.2, 0, 50.4, 25.2, '1LDK', 39.98, 1, 37, 1)
# (112, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '10', 24.5, 15000, 24.5, 24.5, '1LDK', 39.98, 1, 37, 1)
# (113, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '19', 29.5, 0, 29.5, 29.5, '1LDK', 44.74, 1, 37, 1)
# (114, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '11', 29.6, 10000, 29.6, 29.6, '1LDK', 46.0, 1, 37, 1)
# (116, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '24', 30.5, 15000, 30.5, 30.5, '1LDK', 42.34, 1, 37, 1)
# (117, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '4', 32.0, 13000, 48.0, 32.0, '1LDK', 51.06, 1, 37, 1)
# (118, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '13', 35.0, 0, 70.0, 70.0, '1LDK', 48.36, 1, 37, 1)
# (119, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '32', 45.0, 0, 45.0, 45.0, '2LDK', 61.95, 1, 37, 2)
# (120, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '16', 46.0, 20000, 46.0, 46.0, '2LDK', 58.01, 1, 37, 2)
# (121, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '20', 48.0, 20000, 96.0, 48.0, '1LDK', 60.69, 1, 37, 1)
# (122, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '37', 58.0, 0, 58.0, 58.0, '2LDK', 63.63, 1, 37, 2)
# (123, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '37', 58.0, 0, 58.0, 58.0, '2LDK', 63.78, 1, 37, 2)
# (125, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '30', 58.0, 0, 58.0, 58.0, '2LDK', 63.63, 1, 37, 2)
# (126, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '29', 79.8, 0, 79.8, 79.8, '3LDK', 78.03, 1, 37, 3)
# (127, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '33', 83.0, 0, 83.0, 83.0, '3LDK', 87.56, 1, 37, 3)
# (128, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '29', 83.0, 0, 83.0, 83.0, '3LDK', 87.56, 1, 37, 3)
# (129, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '29', 88.0, 0, 88.0, 88.0, '3LDK', 78.03, 1, 37, 3)
# (130, 'パークコート浜離宮ザ\u3000タワー', '東京都港区浜松町１', 'ＪＲ山手線/浜松町駅 歩6分', '都営大江戸線/大門駅 歩5分', 'ＪＲ京浜東北線/新橋駅 歩11分', 5, 38, '31', 87.0, 30000, 87.0, 87.0, '3LDK', 87.56, 1, 37, 3)
# (131, 'エルスタンザ白金台', '東京都港区白金台２', '都営浅草線/高輪台駅 歩5分', '東京メトロ南北線/白金台駅 歩7分', 'ＪＲ山手線/品川駅 歩15分', 17, 11, '7', 17.5, 10000, 17.5, 0.0, '1LDK', 38.86, 0, 11, 1)
# (132, 'エルスタンザ白金台', '東京都港区白金台２', '都営浅草線/高輪台駅 歩5分', '東京メトロ南北線/白金台駅 歩7分', 'ＪＲ山手線/品川駅 歩15分', 17, 11, '7', 17.6, 10000, 17.6, 0.0, '1LDK', 38.96, 0, 11, 1)
# (133, 'エルスタンザ白金台', '東京都港区白金台２', '都営浅草線/高輪台駅 歩5分', '東京メトロ南北線/白金台駅 歩7分', 'ＪＲ山手線/品川駅 歩15分', 17, 11, '9', 23.1, 15000, 23.1, 0.0, '1LDK', 50.8, 0, 11, 1)
# (134, 'レジディア芝浦ＫＡＩＧＡＮ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩3分', '新交通ゆりかもめ/日の出駅 歩12分', 'ＪＲ山手線/田町駅 歩11分', 14, 12, '7', 16.0, 15000, 16.0, 0.0, '1', 44.82, 0, 12, 1)
# (135, 'レジディア芝浦ＫＡＩＧＡＮ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩3分', '新交通ゆりかもめ/日の出駅 歩12分', 'ＪＲ山手線/田町駅 歩11分', 14, 12, '8', 16.1, 15000, 16.1, 16.1, '1LDK', 44.82, 0, 12, 1)
# (136, 'レジディア芝浦ＫＡＩＧＡＮ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩3分', '新交通ゆりかもめ/日の出駅 歩12分', 'ＪＲ山手線/田町駅 歩11分', 14, 12, '4', 17.5, 15000, 17.5, 17.5, '1LDK', 44.82, 0, 12, 1)
# (137, 'レジディア芝浦ＫＡＩＧＡＮ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 �
'東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '2', 18.7, 20000, 18.7, 0.0, '1DK', 30.17, 0, 12, 1)
# (188, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '5', 19.0, 20000, 19.0, 0.0, '1DK', 28.97, 0, 12, 1)
# (189, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '7', 19.3, 20000, 19.3, 0.0, '1DK', 28.97, 0, 12, 1)
# (190, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '2', 19.5, 20000, 19.5, 0.0, '1DK', 31.58, 0, 12, 1)
# (191, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '6', 19.6, 20000, 19.6, 0.0, '1DK', 30.17, 0, 12, 1)
# (192, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '6', 19.7, 20000, 19.7, 0.0, '1DK', 31.58, 0, 12, 1)
# (193, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '3', 19.8, 20000, 19.8, 0.0, '1DK', 30.46, 0, 12, 1)
# (194, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '4', 20.3, 20000, 20.3, 0.0, '1DK', 29.2, 0, 12, 1)
# (195, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '7', 20.7, 20000, 20.7, 0.0, '1DK', 31.58, 0, 12, 1)
# (196, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '5', 21.1, 20000, 21.1, 0.0, '1DK', 30.46, 0, 12, 1)
# (197, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '4', 21.2, 20000, 21.2, 0.0, '1LDK', 30.17, 0, 12, 1)
# (198, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '10', 42.0, 30000, 42.0, 0.0, '1LDK', 52.05, 0, 12, 1)
# (199, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '12', 49.0, 30000, 49.0, 0.0, '1LDK', 52.05, 0, 12, 1)
# (200, '東京メトロ銀座線 表参道駅 12階建 新築', '東京都港区南青山７', '東京メトロ銀座線/表参道駅 歩10分', '東京メトロ日比谷線/広尾駅 歩14分', 'ＪＲ山手線/渋谷駅 歩20分', 0, 12, '7', 55.0, 30000, 55.0, 0.0, '2LDK', 59.66, 0, 12, 2)
# (201, 'trias561 トリアス561', '東京都港区白金５', '東京メトロ南北線/白金高輪駅 歩8分', '東京メトロ日比谷線/広尾駅 歩14分', '東京メトロ南北線/白金台駅 歩16分', 2, 4, '1', 18.6, 18000, 0.0, 0.0, '1LDK', 37.0, 0, 4, 1)
# (202, '出雲白金', '東京都港区白金１', '都営三田線/白金高輪駅 歩3分', '都営浅草線/泉岳寺駅 歩14分', '東京メトロ南北線/麻布十番駅 歩15分', 5, 9, '6', 22.3, 17000, 0.0, 22.3, '1LDK', 44.62, 0, 9, 1)
# (203, '出雲白金', '東京都港区白金１', '都営三田線/白金高輪駅 歩3分', '都営浅草線/泉岳寺駅 歩14分', '東京メトロ南北線/麻布十番駅 歩15分', 5, 9, '6', 22.5, 17000, 0.0, 22.5, '1LDK', 44.62, 0, 9, 1)
# (204, '出雲白金', '東京都港区白金１', '都営三田線/白金高輪駅 歩3分', '都営浅草線/泉岳寺駅 歩14分', '東京メトロ南北線/麻布十番駅 歩15分', 5, 9, '5', 23.5, 18000, 23.5, 23.5, '1LDK', 44.62, 0, 9, 1)
# (205, '東京ツインパークス\u3000ライトウイング', '東京都港区東新橋１', '新交通ゆりかもめ/汐留駅 歩2分', '新交通ゆりかもめ/新橋駅 歩8分', '東京モノレール/浜松町駅 歩18分', 22, 49, '9', 24.5, 15000, 24.5, 24.5, '1LDK', 41.98, 0, 49, 1)
# (249, 'グランスイート虎ノ門', '東京都港区虎ノ門１', '東京メトロ銀座線/虎ノ門駅 歩2分', 'ＪＲ山手線/新橋駅 歩13分', '東京メトロ日比谷線/神谷町駅 歩9分', 17, 22, '9', 28.0, 0, 28.0, 28.0, '1LDK', 49.55, 1, 21, 1)
# (250, 'グランスイート虎ノ門', '東京都港区虎ノ門１', '東京メトロ銀座線/虎ノ門駅 歩2分', 'ＪＲ山手線/新橋駅 歩13分', '東京メトロ日比谷線/神谷町駅 歩9分', 17, 22, '14', 27.2, 10000, 27.2, 54.4, '1LDK', 49.55, 1, 21, 1)
# (251, '都営三田線 御成門駅 15階建 築9年', '東京都港区西新橋３', '都営三田線/御成門駅 歩7分', '東京メトロ日比谷線/虎ノ門ヒルズ駅 歩6分', '東京メトロ銀座線/虎ノ門駅 歩10分', 9, 15, '3', 11.5, 10000, 11.5, 17.25, '1K', 25.6, 0, 15, 1)
# (252, '都営三田線 御成門駅 15階建 築9年', '東京都港区西新橋３', '都営三田線/御成門駅 歩7分', '東京メトロ日比谷線/虎ノ門ヒルズ駅 歩6分', '東京メトロ銀座線/虎ノ門駅 歩10分', 9, 15, '14', 12.05, 10000, 12.05, 24.1, '1DK', 25.6, 0, 15, 1)
# (256, '都営三田線 御成門駅 15階建 築9年', '東京都港区西新橋３', '都営三田線/御成門駅 歩7分', '東京メトロ日比谷線/虎ノ門ヒルズ駅 歩6分', '東京メトロ銀座線/虎ノ門駅 歩10分', 9, 15, '11', 15.9, 11000, 0.0, 15.9, '1DK', 25.6, 0, 15, 1)
# (257, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '4', 17.5, 11000, 17.5, 35.0, '1', 47.88, 2, 56, 1)
# (258, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '12', 18.5, 11000, 18.5, 37.0, '1K', 43.34, 2, 56, 1)
# (259, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '8', 19.5, 11000, 19.5, 39.0, '1SK', 50.99, 2, 56, 1)
# (260, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '14', 23.9, 11000, 23.9, 47.8, '1LDK', 56.93, 2, 56, 1)
# (261, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '11', 24.0, 11000, 24.0, 48.0, '2DK', 59.39, 2, 56, 2)
# (262, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '34', 24.0, 11000, 24.0, 48.0, '1LDK', 46.58, 2, 56, 1)
# (263, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '43', 28.3, 11000, 28.3, 56.6, '1LDK', 67.57, 2, 56, 1)
# (264, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '12', 29.7, 11000, 29.7, 59.4, '3LDK', 75.24, 2, 56, 3)
# (265, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '23', 33.5, 10000, 33.5, 67.0, '2SLDK', 85.09, 2, 56, 2)
# (266, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '23', 33.5, 11000, 33.5, 67.0, '2SLDK', 85.09, 2, 56, 2)
# (267, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '34', 35.7, 11000, 35.7, 71.4, '2LDK', 89.22, 2, 56, 2)
# (268, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '36', 35.8, 11000, 35.8, 71.6, '2LDK', 89.22, 2, 56, 2)
# (269, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '38', 35.8, 11000, 35.8, 71.6, '2LDK', 89.22, 2, 56, 2)
# (270, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '45', 87.0, 0, 174.0, 0.0, '2LDK', 103.1, 2, 56, 2)
# (271, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '45', 93.0, 0, 186.0, 0.0, '2LDK', 113.9, 2, 56, 2)
# (272, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '49', 93.0, 0, 186.0, 0.0, '2LDK', 113.9, 2, 56, 2)
# (273, 'アクティ汐留', '東京都港区海岸１', 'ＪＲ京浜東北線/浜松町駅 歩3分', '都営大江戸線/大門駅 歩4分', '新交通ゆりかもめ/竹芝駅 歩10分', 20, 58, '49', 94.0, 0, 188.0, 0.0, '2LDK', 113.9, 2, 56, 2)
# (274, 'ベイサイドステージ東京', '東京都港区海岸２', 'ＪＲ山手線/浜松町駅 歩12分', '新交通ゆりかもめ/日の出駅 歩2分', '都営浅草線/三田駅 歩16分', 23, 14, '11', 22.0, 20000, 22.0, 0.0, '2LDK', 68.4, 0, 14, 2)
# (275, 'カスタリア南麻布', '東京都港区南麻布２', '東京メトロ南北線/麻布十番駅 歩8分', '都営三田線/白金高輪駅 歩13分', '都営大江戸線/赤羽橋駅 歩19分', 20, 6, '4', 21.2, 6000, 21.2, 0.0, '2DK', 51.07, 0, 6, 2)
# (276, 'カスタリア南麻布', '東京都港区南麻布２', '東京メトロ南北線/麻布十番駅 歩8分', '都営三田線/白金高輪駅 歩13分', '都営大江戸線/赤羽橋駅 歩19分', 20, 6, '4', 21.9, 6000, 21.9, 0.0, '2DK', 51.07, 0, 6, 2)
# (277, 'カスタリア南麻布', '東京都港区南麻布２', '東京メトロ南北線/麻布十番駅 歩8分', '都営三田線/白金高輪駅 歩13分', '都営大江戸線/赤羽橋駅 歩19分', 20, 6, '4', 22.8, 6000, 22.8, 0.0, '2LDK', 51.07, 0, 6, 2)
# (278, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '13', 13.5, 0, 13.5, 13.5, '1K', 25.13, 1, 32, 1)
# (279, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '3', 14.0, 0, 14.0, 14.0, '1K', 25.13, 1, 32, 1)
# (280, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '4', 13.2, 10000, 13.2, 13.2, '1', 25.2, 1, 32, 1)
# (281, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '4', 14.3, 0, 14.3, 14.3, '1K', 25.13, 1, 32, 1)
# (282, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '9', 14.3, 0, 14.3, 14.3, '1', 25.13, 1, 32, 1)
# (283, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '4', 14.5, 0, 14.5, 14.5, '1', 25.49, 1, 32, 1)
# (284, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '5', 14.5, 0, 14.5, 0.0, '1', 25.13, 1, 32, 1)
# (285, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '6', 14.5, 0, 14.5, 14.5, '1K', 25.13, 1, 32, 1)
# (286, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '5', 14.8, 0, 14.8, 0.0, '1K', 25.13, 1, 32, 1)
# (287, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '11', 13.9, 10000, 13.9, 13.9, '1K', 25.13, 1, 32, 1)
# (288, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '10', 14.9, 0, 14.9, 14.9, '1K', 25.13, 1, 32, 1)
# (289, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '6', 15.0, 0, 15.0, 15.0, '1', 25.49, 1, 32, 1)
# (290, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '10', 14.0, 10000, 14.0, 14.0, '1', 25.18, 1, 32, 1)
# (291, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '8', 13.5, 15000, 13.5, 13.5, '1K', 25.13, 1, 32, 1)
# (292, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '8', 15.0, 0, 15.0, 15.0, '1', 25.13, 1, 32, 1)
# (293, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '14', 15.0, 0, 15.0, 15.0, '1', 25.13, 1, 32, 1)
# (294, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '14', 14.0, 10000, 14.0, 14.0, '1', 25.13, 1, 32, 1)
# (295, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '8', 15.2, 0, 15.2, 15.2, '1', 25.49, 1, 32, 1)
# (296, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '11', 14.2, 10000, 14.2, 14.2, '1DK', 25.13, 1, 32, 1)
# (297, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '11', 15.2, 0, 15.2, 15.2, '1K', 25.13, 1, 32, 1)
# (299, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '11', 14.8, 5000, 14.8, 14.8, '1', 25.2, 1, 32, 1)
# (300, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '11', 14.8, 5000, 14.8, 14.8, '1', 25.18, 1, 32, 1)
# (301, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '12', 15.4, 0, 15.4, 15.4, '1', 25.13, 1, 32, 1)
# (302, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '15', 15.4, 0, 15.4, 30.8, '1K', 25.13, 1, 32, 1)
# (303, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '10', 15.5, 0, 15.5, 15.5, '1K', 25.2, 1, 32, 1)
# (304, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '13', 15.5, 0, 15.5, 15.5, '1', 25.18, 1, 32, 1)
# (305, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '14', 14.5, 10000, 14.5, 14.5, '1K', 25.13, 1, 32, 1)
# (306, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '13', 14.5, 10000, 14.5, 14.5, '1K', 25.13, 1, 32, 1)
# (308, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '9', 13.7, 18000, 13.7, 13.7, '1K', 25.13, 1, 32, 1)
# (309, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '6', 14.0, 15000, 14.0, 21.0, '1K', 25.13, 1, 32, 1)
# (310, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '15', 14.9, 6000, 14.9, 14.9, '1K', 25.13, 1, 32, 1)
# (311, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '16', 14.2, 13000, 14.2, 14.2, '1K', 25.13, 1, 32, 1)
# (312, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '7', 14.5, 12000, 7.25, 0.0, '1', 25.13, 1, 32, 1)
# (313, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '16', 15.8, 0, 15.8, 15.8, '1K', 25.13, 1, 32, 1)
# (314, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '14', 15.0, 10000, 15.0, 15.0, '1', 25.49, 1, 32, 1)
# (315, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '16', 16.0, 0, 16.0, 16.0, '1', 25.18, 1, 32, 1)
# (316, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '16', 16.0, 0, 16.0, 16.0, '1K', 25.13, 1, 32, 1)
# (317, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '15', 15.0, 10000, 15.0, 15.0, '1', 25.13, 1, 32, 1)
# (318, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '17', 15.0, 10000, 15.0, 15.0, '1K', 25.13, 1, 32, 1)
# (319, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '4', 15.5, 5000, 15.5, 15.5, '1K', 25.13, 1, 32, 1)
# (320, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '6', 16.0, 0, 16.0, 16.0, '1K', 25.13, 1, 32, 1)
# (321, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '10', 16.3, 0, 16.3, 32.6, '1', 25.49, 1, 32, 1)
# (322, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '12', 16.3, 0, 16.3, 32.6, '1', 25.18, 1, 32, 1)
# (323, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '7', 15.5, 10000, 15.5, 15.5, '1', 25.13, 1, 32, 1)
# (324, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '16', 16.5, 0, 16.5, 16.5, '1', 25.13, 1, 32, 1)
# (325, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '7', 18.0, 0, 18.0, 18.0, '1', 25.13, 1, 32, 1)
# (327, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '15', 17.8, 9300, 17.8, 17.8, '1K', 25.13, 1, 32, 1)
# (328, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '17', 18.0, 9300, 18.0, 18.0, '1DK', 25.13, 1, 32, 1)
# (329, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '16', 20.0, 0, 20.0, 20.0, '1', 25.13, 1, 32, 1)
# (330, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '6', 25.0, 0, 25.0, 25.0, '1LDK', 40.69, 1, 32, 1)
# (331, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '15', 25.0, 0, 25.0, 25.0, '1LDK', 40.08, 1, 32, 1)
# (332, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '7', 26.0, 0, 26.0, 0.0, '1LDK', 40.69, 1, 32, 1)
# (333, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '5', 26.2, 0, 26.2, 26.2, '1LDK', 43.84, 1, 32, 1)
# (334, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '7', 27.0, 0, 27.0, 27.0, '1LDK', 45.94, 1, 32, 1)
# (335, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '5', 26.0, 10000, 26.0, 26.0, '1LDK', 45.94, 1, 32, 1)
# (336, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '11', 27.5, 0, 27.5, 27.5, '1LDK', 43.84, 1, 32, 1)
# (337, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '15', 29.0, 0, 29.0, 29.0, '1LDK', 43.81, 1, 32, 1)
# (339, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '8', 29.0, 0, 29.0, 29.0, '1LDK', 40.08, 1, 32, 1)
# (340, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '17', 30.0, 0, 30.0, 30.0, '1LDK', 43.89, 1, 32, 1)
# (341, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '18', 30.0, 0, 30.0, 30.0, '1LDK', 43.67, 1, 32, 1)
# (342, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '9', 31.0, 15000, 31.0, 46.5, '1LDK', 45.94, 1, 32, 1)
# (343, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '30', 34.5, 15000, 34.5, 34.5, '2LDK', 58.91, 1, 32, 2)
# (344, 'ブリリアタワー浜離宮', '東京都港区海岸１', 'ＪＲ山手線/浜松町駅 歩5分', '都営浅草線/大門駅 歩9分', '新交通ゆりかもめ/竹芝駅 歩2分', 0, 33, '19', 37.0, 25000, 37.0, 0.0, '2LDK', 62.58, 1, 32, 2)
# ...
# (2434, 'パークハビオ新橋', '東京都港区新橋５', 'ＪＲ山手線/新橋駅 歩9分', '都営三田線/御成門駅 歩4分', '都営三田線/内幸町駅 歩9分', 11, 16, '10', 12.9, 10000, 12.9, 12.9, '1', 25.27, 1, 15, 1)
# (2435, 'パークハビオ新橋', '東京都港区新橋５', 'ＪＲ山手線/新橋駅 歩9分', '都営三田線/御成門駅 歩4分', '都営三田線/内幸町駅 歩9分', 11, 16, '12', 13.2, 10000, 13.2, 13.2, '1', 25.27, 1, 15, 1)
# (2436, '都営三田線 御成門駅 15階建 築8年', '東京都港区新橋５', '都営三田線/御成門駅 歩6分', '新交通ゆりかもめ/汐留駅 歩8分', '都営浅草線/新橋駅 歩8分', 8, 15, '2', 10.6, 10000, 10.6, 0.0, '1', 22.05, 0, 15, 1)
# (2437, '都営三田線 御成門駅 15階建 築8年', '東京都港区新橋５', '都営三田線/御成門駅 歩6分', '新交通ゆりかもめ/汐留駅 歩8分', '都営浅草線/新橋駅 歩8分', 8, 15, '5', 11.0, 10000, 11.0, 0.0, '1', 22.05, 0, 15, 1)
# (2438, '都営三田線 御成門駅 15階建 築8年', '東京都港区新橋５', '都営三田線/御成門駅 歩6分', '新交通ゆりかもめ/汐留駅 歩8分', '都営浅草線/新橋駅 歩8分', 8, 15, '8', 12.5, 10000, 12.5, 0.0, '1', 25.52, 0, 15, 1)
# (2442, '元麻布フォレストプラザ3', '東京都港区元麻布２', '東京メトロ南北線/麻布十番駅 歩8分', '東京メトロ日比谷線/六本木駅 歩12分', '東京メトロ日比谷線/広尾駅 歩13分', 25, 3, '2', 19.9, 20000, 19.9, 0.0, '2DK', 49.55, 0, 3, 2)
# (2541, 'ピアース南麻布', '東京都港区南麻布２', '東京メトロ南北線/白金高輪駅 歩5分', '東京メトロ南北線/麻布十番駅 歩13分', '京急本線/泉岳寺駅 歩17分', 6, 13, '2', 12.0, 10000, 12.0, 12.0, '1K', 25.41, 0, 13, 1)
# (2542, 'ピアース南麻布', '東京都港区南麻布２', '東京メトロ南北線/白金高輪駅 歩5分', '東京メトロ南北線/麻布十番駅 歩13分', '京急本線/泉岳寺駅 歩17分', 6, 13, '2', 12.5, 12000, 12.5, 12.5, '1K', 22.33, 0, 13, 1)
# (2543, 'ピアース南麻布', '東京都港区南麻布２', '東京メトロ南北線/白金高輪駅 歩5分', '東京メトロ南北線/麻布十番駅 歩13分', '京急本線/泉岳寺駅 歩17分', 6, 13, '10', 13.2, 10000, 13.2, 13.2, '1K', 25.62, 0, 13, 1)
# (2544, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '9', 14.9, 8000, 29.8, 0.0, '1LDK', 45.08, 1, 18, 1)
# (2545, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '9', 15.4, 8000, 30.8, 0.0, '1LDK', 45.08, 1, 18, 1)
# (2546, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '4', 15.9, 8000, 31.8, 0.0, '1LDK', 53.55, 1, 18, 1)
# (2547, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '5', 16.1, 8000, 32.2, 0.0, '1LDK', 53.55, 1, 18, 1)
# (2548, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '9', 16.7, 8000, 33.4, 0.0, '1LDK', 53.55, 1, 18, 1)
# (2549, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '13', 16.8, 8000, 33.6, 0.0, '1LDK', 53.55, 1, 18, 1)
# (2550, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '14', 17.0, 8000, 34.0, 0.0, '1LDK', 53.55, 1, 18, 1)
# (2551, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '13', 17.0, 8000, 34.0, 0.0, '1LDK', 53.55, 1, 18, 1)
# (2552, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 歩7分', 'ＪＲ山手線/田町駅 歩12分', '都営浅草線/三田駅 歩20分', 33, 19, '3', 17.2, 8000, 34.4, 0.0, '1LDK', 53.55, 1, 18, 1)
# (2553, 'ＬＯＯＰーＭ', '東京都港区海岸３', '新交通ゆりかもめ/芝浦ふ頭駅 �